# %% [raw]
# ---
# title: "NASA Earthdata Catalog"
# author: Eli Holmes (NOAA)
# ---

# %% [markdown]
# [![Colab Badge](https://img.shields.io/badge/Open_in_Colab-blue?style=for-the-badge)][colab-link]
# <a href="javascript:void(0);" onclick="openJupyterWidget('https://github.com/nmfs-opensci/EDMW-EarthData-Workshop-2025/blob/main/tutorials/clean/Tutorial_0_search.ipynb');">
#     <img src="https://img.shields.io/badge/Open_in_JupyterHub-orange?style=for-the-badge" alt="JupyterHub Badge">
# </a> [![Download Badge](https://img.shields.io/badge/Download-grey?style=for-the-badge)][download-link] [![JupyterHub](https://img.shields.io/badge/Workshop_Hub-green?style=for-the-badge)][jupyter-link]
#
# [download-link]: https://github.com/nmfs-opensci/EDMW-EarthData-Workshop-2025/blob/main/tutorials/clean/Tutorial_0_search.ipynb
# [colab-link]: https://colab.research.google.com/github/nmfs-opensci/EDMW-EarthData-Workshop-2025/blob/main/tutorials/clean/Tutorial_0_search.ipynb
# [jupyter-link]: https://workshop.nmfs-openscapes.2i2c.cloud/hub/user-redirect/lab?fromURL=https://raw.githubusercontent.com/nmfs-opensci/EDMW-EarthData-Workshop-2025/main/tutorials/clean/Tutorial_0_search.ipynb

# %% [markdown]
# >📘 Learning Objectives
# >
# > 1. Authenticate to NASA Earthdata
# > 2. Find collection information from the Earthdata catalog.

# %% [markdown]
# ## Summary
#
# In this tutorial, we will get to know the NASA Earthdata catalog and assets. And learn how to get information on data collections.
#
# ## Earthdata Login account
#
# An Earthdata Login account is required to access data from NASA Earthdata. Please visit <https://urs.earthdata.nasa.gov> to register and manage your Earthdata Login account. This account is free to create and only takes a moment to set up.

# %% [markdown]
# ### The Earthdata catalog search page
#
# How can we find the `shortname` and/or `concept_id` for data collections?. We can find these on the NASA Earthdata catalog search page and data collection pages.
#
# Let's head to <https://search.earthdata.nasa.gov/search>. Here is the front page. On the top left, you can type in text to search and below you can filter on specific criteria, like instrument. On the right are lists of data collections. Let's look at the information for a data collection.

# %% [markdown]
# ![search-earthdata.png](attachment:23f8e678-e2a6-4daf-9648-0aef031333fc.png)

# %% [markdown]
# ## Search for a dataset
#
# Here I did a search for "MUR-JPL-L4-GLOB-v4.1" and the GHRSST Level 4 dataset is at the top. Click on the i with the circle to get the collection details on the GHRSST dataset.

# %% [markdown]
# ![image.png](attachment:c25bc7c7-bbca-41d0-8028-eaf82df22815.png)

# %% [markdown]
# ### Data collection details
#
# The collection details page has some keywords that can be used to specify a collection. In the red box, is the `shortname` (MUR-JPL-L4-GLOB-v4.1), `version` (4.1) and `doi`. Click on the View More Info to find the collection `concept_id`.

# %% [markdown]
# ![search-collection-details.png](attachment:9d661842-27a4-4aab-b0d1-ce4a32575ada.png)

# %% [markdown]
# ## Concept ID
#
# The concept ID is the long string to the left of the version.

# %% [markdown]
# ![search-collection-id.png](attachment:3f89fc02-ae2f-4f44-8155-41dc056b4b31.png)

# %% [markdown]
# ### Example of some collection identifiers
#
# You typically only need one of these.
#
# | Shortname | Collection Concept ID | DOI |
# | --- | --- | --- |
# | MUR-JPL-L4-GLOB-v4.1 | C1996881146-POCLOUD | 10.5067/GHGMR-4FJ04 |
# | AVHRR_OI-NCEI-L4-GLOB-v2.1 | C2036881712-POCLOUD | 10.5067/GHAAO-4BC21 |

# %% [markdown]
# ## Try this for PACE
#
# Paste this into a browser.
# ```
# https://search.earthdata.nasa.gov/search?fi=OCI&fl=3%2B-%2BGridded%2BObservations
# ```
#
# 1. Filter on instrument "OCI"
# 2. Filter of processing level 4
# 3. Scroll through the collections to find what you want
#
# ## Summary
#
# This concludes the introduction to the NASA Earthdata collection identifiers. With the information in the table above, we will use the Python `earthaccess` library to search the files in collections in the next tutorial.

# %% [markdown]
# ---
